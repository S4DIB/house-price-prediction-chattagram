# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv("/kaggle/input/house-price-bangladesh/house_price_bd.csv")
df
# Out:
#                                                   Title  Bedrooms  Bathrooms  \
# 0     We Are Offering You A Very Spacious 1960 Sq Ft...       3.0        4.0
# 1     Valuable 1705 Square Feet Apartment Is Ready T...       3.0        3.0
# 2     1370 square feet apartment is ready to sale in...       3.0        3.0
# 3     2125 Square Feet Apartment For Sale In Bashund...       3.0        3.0
# 4     Buy This 2687 Square Feet Flat In The Nice Are...       3.0        3.0
# ...                                                 ...       ...        ...
# 3860  Buy This 1350 Sq Ft Amazing Flat In Gazipur, J...       3.0        3.0
# 3861  Properly Designed This 1000 Square Feet Apartm...       2.0        2.0
# 3862  1240 Sq Ft Flat For Sale Is Awaiting You In Ga...       3.0        3.0
# 3863  An Apartment Of 1300 Sq Ft Is Up For Sale In J...       3.0        3.0
# 3864  1350 Sq Ft Residential Apartment For Sale In G...       3.0        3.0
#
# ...

# %%
df.head()
# Out:
#                                                Title  Bedrooms  Bathrooms  \
# 0  We Are Offering You A Very Spacious 1960 Sq Ft...       3.0        4.0
# 1  Valuable 1705 Square Feet Apartment Is Ready T...       3.0        3.0
# 2  1370 square feet apartment is ready to sale in...       3.0        3.0
# 3  2125 Square Feet Apartment For Sale In Bashund...       3.0        3.0
# 4  Buy This 2687 Square Feet Flat In The Nice Are...       3.0        3.0
#
#   Floor_no Occupancy_status  Floor_area   City Price_in_taka  \
# 0        3           vacant      1960.0  dhaka   ৳39,000,000
# 1        1           vacant      1705.0  dhaka   ৳16,900,000
# 2        6           vacant      1370.0  dhaka   ৳12,500,000
# 3        4           vacant      2125.0  dhaka   ৳20,000,000
# 4        4           vacant      2687.0  dhaka   ৳47,500,000
#
#                       Location
# 0           Gulshan 1, Gulshan
# 1  Lake Circus Road, Kalabagan
# 2         Shukrabad, Dhanmondi
# ...

# %%
df.shape
# Out:
# (3865, 9)

# %%
null = df.isnull().sum()
null
# Out:
# Title                  0
# Bedrooms            1001
# Bathrooms           1001
# Floor_no             684
# Occupancy_status      99
# Floor_area            99
# City                   0
# Price_in_taka          0
# Location               6
# dtype: int64

# %%
df.dtypes
# Out:
# Title                object
# Bedrooms            float64
# Bathrooms           float64
# Floor_no             object
# Occupancy_status     object
# Floor_area          float64
# City                 object
# Price_in_taka        object
# Location             object
# dtype: object

# %%
df_chattogram = df[df["City"] == "chattogram"]
df_chattogram
# Out:
#                                                   Title  Bedrooms  Bathrooms  \
# 1650     At Chandgong R/A 1650 Sq.ft Apartment For Sale       3.0        3.0
# 1651  Buy This 2079 Sq Ft Flat In 15 No. Bagmoniram ...       4.0        5.0
# 1652  This 1644 Sq Ft Flat Is Up For Sale Within You...       3.0        3.0
# 1653  Look At This Nice 2200 Sq Ft Flat Is Up For Sa...       3.0        3.0
# 1654  1620 Sq Ft Apartment Is Up For Sale In Muradpu...       3.0        3.0
# ...                                                 ...       ...        ...
# 3115  200 Sq Ft Commercial Shop Is Available For Sal...       NaN        NaN
# 3116                 Buy This 240 Sq Ft Shop At Bakalia       NaN        NaN
# 3117  Bakalia Is Giving You A 240 Sq Ft Commercial S...       NaN        NaN
# 3118  105 Sq Ft Commercial Shop For Sale At The Loca...       NaN        NaN
# 3119  Appealing Property In Bayazid– 1295 Sq Ft Flat...       3.0        3.0
#
# ...

# %%
df_chattogram = df_chattogram.drop("Title", axis=1)
df_chattogram
# Out:
#       Bedrooms  Bathrooms Floor_no Occupancy_status  Floor_area        City  \
# 1650       3.0        3.0        1           vacant      1650.0  chattogram
# 1651       4.0        5.0        5           vacant      2079.0  chattogram
# 1652       3.0        3.0        9           vacant      1644.0  chattogram
# 1653       3.0        3.0        8           vacant      2200.0  chattogram
# 1654       3.0        3.0        8           vacant      1620.0  chattogram
# ...        ...        ...      ...              ...         ...         ...
# 3115       NaN        NaN        4           vacant       200.0  chattogram
# 3116       NaN        NaN        4           vacant       240.0  chattogram
# 3117       NaN        NaN        4           vacant       240.0  chattogram
# 3118       NaN        NaN        1           vacant       105.0  chattogram
# 3119       3.0        3.0        5           vacant      1295.0  chattogram
#
# ...

# %%
df_chattogram = df_chattogram.reset_index(drop=True)
df_chattogram
# Out:
#       Bedrooms  Bathrooms Floor_no Occupancy_status  Floor_area        City  \
# 0          3.0        3.0        1           vacant      1650.0  chattogram
# 1          4.0        5.0        5           vacant      2079.0  chattogram
# 2          3.0        3.0        9           vacant      1644.0  chattogram
# 3          3.0        3.0        8           vacant      2200.0  chattogram
# 4          3.0        3.0        8           vacant      1620.0  chattogram
# ...        ...        ...      ...              ...         ...         ...
# 1465       NaN        NaN        4           vacant       200.0  chattogram
# 1466       NaN        NaN        4           vacant       240.0  chattogram
# 1467       NaN        NaN        4           vacant       240.0  chattogram
# 1468       NaN        NaN        1           vacant       105.0  chattogram
# 1469       3.0        3.0        5           vacant      1295.0  chattogram
#
# ...

# %%
df_chattogram.isnull().sum()
# Out:
# Bedrooms            375
# Bathrooms           375
# Floor_no            127
# Occupancy_status     26
# Floor_area           26
# City                  0
# Price_in_taka         0
# Location              5
# dtype: int64

# %%
df_chattogram = df_chattogram.dropna(how='any')
df_chattogram
# Out:
#       Bedrooms  Bathrooms Floor_no Occupancy_status  Floor_area        City  \
# 0          3.0        3.0        1           vacant      1650.0  chattogram
# 1          4.0        5.0        5           vacant      2079.0  chattogram
# 2          3.0        3.0        9           vacant      1644.0  chattogram
# 3          3.0        3.0        8           vacant      2200.0  chattogram
# 4          3.0        3.0        8           vacant      1620.0  chattogram
# ...        ...        ...      ...              ...         ...         ...
# 1460       3.0        3.0        4           vacant      1650.0  chattogram
# 1461       2.0        2.0        3           vacant      1050.0  chattogram
# 1462       3.0        3.0        5           vacant      1035.0  chattogram
# 1463      27.0       10.0        5           vacant     12000.0  chattogram
# 1469       3.0        3.0        5           vacant      1295.0  chattogram
#
# ...

# %%
df_chattogram.isnull().sum()
# Out:
# Bedrooms            0
# Bathrooms           0
# Floor_no            0
# Occupancy_status    0
# Floor_area          0
# City                0
# Price_in_taka       0
# Location            0
# dtype: int64

# %%
df_chattogram.isna().sum()
# Out:
# Bedrooms            0
# Bathrooms           0
# Floor_no            0
# Occupancy_status    0
# Floor_area          0
# City                0
# Price_in_taka       0
# Location            0
# dtype: int64

# %%
df_chattogram.dtypes
# Out:
# Bedrooms            float64
# Bathrooms           float64
# Floor_no             object
# Occupancy_status     object
# Floor_area          float64
# City                 object
# Price_in_taka        object
# Location             object
# dtype: object

# %%
df_chattogram.loc[:, "Price_in_taka"] = df_chattogram["Price_in_taka"].str.replace("৳", "", regex=False)
df_chattogram
# Out:
#       Bedrooms  Bathrooms Floor_no Occupancy_status  Floor_area        City  \
# 0          3.0        3.0        1           vacant      1650.0  chattogram
# 1          4.0        5.0        5           vacant      2079.0  chattogram
# 2          3.0        3.0        9           vacant      1644.0  chattogram
# 3          3.0        3.0        8           vacant      2200.0  chattogram
# 4          3.0        3.0        8           vacant      1620.0  chattogram
# ...        ...        ...      ...              ...         ...         ...
# 1460       3.0        3.0        4           vacant      1650.0  chattogram
# 1461       2.0        2.0        3           vacant      1050.0  chattogram
# 1462       3.0        3.0        5           vacant      1035.0  chattogram
# 1463      27.0       10.0        5           vacant     12000.0  chattogram
# 1469       3.0        3.0        5           vacant      1295.0  chattogram
#
# ...

# %%
df_chattogram.loc[:, "Price_in_taka"] = df_chattogram["Price_in_taka"].str.replace(",", "", regex=False)
df_chattogram
# Out:
#       Bedrooms  Bathrooms Floor_no Occupancy_status  Floor_area        City  \
# 0          3.0        3.0        1           vacant      1650.0  chattogram
# 1          4.0        5.0        5           vacant      2079.0  chattogram
# 2          3.0        3.0        9           vacant      1644.0  chattogram
# 3          3.0        3.0        8           vacant      2200.0  chattogram
# 4          3.0        3.0        8           vacant      1620.0  chattogram
# ...        ...        ...      ...              ...         ...         ...
# 1460       3.0        3.0        4           vacant      1650.0  chattogram
# 1461       2.0        2.0        3           vacant      1050.0  chattogram
# 1462       3.0        3.0        5           vacant      1035.0  chattogram
# 1463      27.0       10.0        5           vacant     12000.0  chattogram
# 1469       3.0        3.0        5           vacant      1295.0  chattogram
#
# ...

# %%
df_chattogram.dtypes
# Out:
# Bedrooms            float64
# Bathrooms           float64
# Floor_no             object
# Occupancy_status     object
# Floor_area          float64
# City                 object
# Price_in_taka        object
# Location             object
# dtype: object

# %%
df_chattogram['Price_in_taka'] = pd.to_numeric(df_chattogram['Price_in_taka'], errors='coerce')
df_chattogram
# Out:
# /tmp/ipykernel_140/3677547692.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chattogram['Price_in_taka'] = pd.to_numeric(df_chattogram['Price_in_taka'], errors='coerce')
#       Bedrooms  Bathrooms Floor_no Occupancy_status  Floor_area        City  \
# 0          3.0        3.0      1.0           vacant      1650.0  chattogram
# 1          4.0        5.0      5.0           vacant      2079.0  chattogram
# 2          3.0        3.0      9.0           vacant      1644.0  chattogram
# 3          3.0        3.0      8.0           vacant      2200.0  chattogram
# 4          3.0        3.0      8.0           vacant      1620.0  chattogram
# ...        ...        ...      ...              ...         ...         ...
# ...

# %%
df_chattogram['Floor_no'] = pd.to_numeric(df_chattogram['Floor_no'], errors='coerce')
df_chattogram
# Out:
# /tmp/ipykernel_140/3811343866.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chattogram['Floor_no'] = pd.to_numeric(df_chattogram['Floor_no'], errors='coerce')
#       Bedrooms  Bathrooms  Floor_no Occupancy_status  Floor_area        City  \
# 0          3.0        3.0       1.0           vacant      1650.0  chattogram
# 1          4.0        5.0       5.0           vacant      2079.0  chattogram
# 2          3.0        3.0       9.0           vacant      1644.0  chattogram
# 3          3.0        3.0       8.0           vacant      2200.0  chattogram
# 4          3.0        3.0       8.0           vacant      1620.0  chattogram
# ...        ...        ...       ...              ...         ...         ...
# ...

# %%
df_chattogram.isna().sum()
# Out:
# Bedrooms            0
# Bathrooms           0
# Floor_no            6
# Occupancy_status    0
# Floor_area          0
# City                0
# Price_in_taka       0
# Location            0
# dtype: int64

# %%
df_chattogram = df_chattogram.dropna(how='any')
df_chattogram
# Out:
#       Bedrooms  Bathrooms  Floor_no Occupancy_status  Floor_area        City  \
# 0          3.0        3.0       1.0           vacant      1650.0  chattogram
# 1          4.0        5.0       5.0           vacant      2079.0  chattogram
# 2          3.0        3.0       9.0           vacant      1644.0  chattogram
# 3          3.0        3.0       8.0           vacant      2200.0  chattogram
# 4          3.0        3.0       8.0           vacant      1620.0  chattogram
# ...        ...        ...       ...              ...         ...         ...
# 1460       3.0        3.0       4.0           vacant      1650.0  chattogram
# 1461       2.0        2.0       3.0           vacant      1050.0  chattogram
# 1462       3.0        3.0       5.0           vacant      1035.0  chattogram
# 1463      27.0       10.0       5.0           vacant     12000.0  chattogram
# 1469       3.0        3.0       5.0           vacant      1295.0  chattogram
#
# ...

# %%
df_chattogram = df_chattogram.drop(columns=['City'])
df_chattogram
# Out:
#       Bedrooms  Bathrooms  Floor_no Occupancy_status  Floor_area  \
# 0          3.0        3.0       1.0           vacant      1650.0
# 1          4.0        5.0       5.0           vacant      2079.0
# 2          3.0        3.0       9.0           vacant      1644.0
# 3          3.0        3.0       8.0           vacant      2200.0
# 4          3.0        3.0       8.0           vacant      1620.0
# ...        ...        ...       ...              ...         ...
# 1460       3.0        3.0       4.0           vacant      1650.0
# 1461       2.0        2.0       3.0           vacant      1050.0
# 1462       3.0        3.0       5.0           vacant      1035.0
# 1463      27.0       10.0       5.0           vacant     12000.0
# 1469       3.0        3.0       5.0           vacant      1295.0
#
#       Price_in_taka                                           Location
# 0           9075000    Chandgaon Residential Area, 4 No Chandgaon Ward
# ...

# %%
df_chattogram.dtypes
# Out:
# Bedrooms            float64
# Bathrooms           float64
# Floor_no            float64
# Occupancy_status     object
# Floor_area          float64
# Price_in_taka         int64
# Location             object
# dtype: object

# %%
le = LabelEncoder()

# %%
df_chattogram['Occupancy_status_encoded'] = le.fit_transform(df_chattogram['Occupancy_status'])
df_chattogram
# Out:
#       Bedrooms  Bathrooms  Floor_no Occupancy_status  Floor_area  \
# 0          3.0        3.0       1.0           vacant      1650.0
# 1          4.0        5.0       5.0           vacant      2079.0
# 2          3.0        3.0       9.0           vacant      1644.0
# 3          3.0        3.0       8.0           vacant      2200.0
# 4          3.0        3.0       8.0           vacant      1620.0
# ...        ...        ...       ...              ...         ...
# 1460       3.0        3.0       4.0           vacant      1650.0
# 1461       2.0        2.0       3.0           vacant      1050.0
# 1462       3.0        3.0       5.0           vacant      1035.0
# 1463      27.0       10.0       5.0           vacant     12000.0
# 1469       3.0        3.0       5.0           vacant      1295.0
#
#       Price_in_taka                                           Location  \
# 0           9075000    Chandgaon Residential Area, 4 No Chandgaon Ward
# ...
